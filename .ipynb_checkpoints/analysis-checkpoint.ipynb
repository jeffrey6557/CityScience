# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os, sys 
import pandas as pd
# you don't have to use seaborn if you prefer plain matplotlib
import seaborn as sns
import numpy as np
import numpy.random as npr
import pylab

sns.set_style('white')
sns.set_context('paper')

# %%
aPath='/Users/liuchang/Documents/STUDY/Projects/CityScience'
os.chdir(aPath)

# %%
# read into a table
df = pd.read_csv("yelp_data_city.csv")
df
# Out:
#                                name  rating  review_count         city  \
# 0               Kaya Street Kitchen     4.5           185  Los Angeles
# 1                          Langer's     4.5          2392  Los Angeles
# 2                          Corn Man     5.0            99  Los Angeles
# 3                          Guisados     4.5          1423  Los Angeles
# 4                   The Black Sheep     4.5           584  Los Angeles
# 5        Dino's Chicken and Burgers     4.5          1254  Los Angeles
# 6                    Bronzed Aussie     4.5           312  Los Angeles
# 7                Ricky's Fish Tacos     4.5           804  Los Angeles
# 8                          Dirt Dog     4.5           126  Los Angeles
# 9                          Guisados     4.5           832  Los Angeles
# 10                Big Al's Pizzeria     5.0           303      Maywood
# 11                          Eggslut     4.0          1342  Los Angeles
# 12     California Gogi Korean Grill     4.5           172  Los Angeles
# 13              Tacos Baja Ensenada     4.5           665  Los Angeles
# 14      Little Jewel of New Orleans     4.5           332  Los Angeles
# 15     Figueroa Philly Cheese Steak     4.5           400  Los Angeles
# 16                   The Hungry Pig     4.5           263  Los Angeles
# 17                    The Black Fig     4.5            48  Los Angeles
# 18                    Belly & Snout     4.5            77  Los Angeles
# 19                 Andrea Salumeria     5.0           115  Jersey City
# 20                   Los Tacos No.1     4.5           545     New York
# 21              Prosperity Dumpling     4.5          2488     New York
# 22        BeeHive Oven Biscuit Cafe     4.5           143     Brooklyn
# 23                      Ace's Wings     5.0            28  Jersey City
# 24                          Upstate     4.5           857     New York
# 25                            Traif     4.5          1349     Brooklyn
# 26                Cheeky Sandwiches     4.5           388     New York
# 27            Fiore Deli of Hoboken     4.5           286      Hoboken
# 28  Hudson Eats At Brookfield Place     4.5            77     New York
# 29                    Uncle Gussy's     4.5           212     New York
# 30                   The Halal Guys     4.5          6039     New York
# 31     Graham Avenue Meats And Deli     4.5           364     Brooklyn
# 32                        Breakroom     4.5           328     New York
# 33                Sunny and Annie's     4.5           226     New York
# 34                  Wafels & Dinges     4.5          1300     New York
# 35                             Bite     4.0           415     New York
# 36                        Nish Nush     4.5           225     New York
# 37       Piperi Mediterranean Grill     4.5           266       Boston
# 38             Giacomo's Ristorante     4.0          1798       Boston
# 39                   Mike & Patty's     4.5           648       Boston
# 40                             Saus     4.0           613       Boston
# 41                     Casa Razdora     4.5           190       Boston
# 42                 Galleria Umberto     4.5           323       Boston
# 15 -118.282349
# 16 -118.279353
# 17 -118.232890
# 18 -118.308917
# 19  -74.051392
# 20  -74.005956
# 21  -73.992996
# 22  -73.960317
# 23  -74.084812
# 24  -73.986490
# 25  -73.958872
# 26  -73.991676
# 27  -74.036263
# 28  -74.015092
# 29  -73.972427
# 30  -73.979230
# 31  -73.945326
# 32  -73.999944
# 33  -73.981585
# 34  -74.009490
# 35  -73.986160
# 36  -74.007695
# 37  -71.060788
# 38  -71.053436
# 39  -71.067703
# 40  -71.057072
# 41  -71.054611
# 42  -71.054450
# 43  -71.091179
# 44  -71.060120
# 45  -71.060698
# 46  -71.056012
# 47  -71.059837
# 48  -71.074730
# 49  -71.079720
# 50  -71.075652
# 51  -71.082527
# 52  -71.055990
# 53  -71.123679
# 54  -71.059764
# 55  -71.088850
# 56  -71.051800

# %%
ratings = df['rating'].values
print 'there are', len(ratings),'ratings in this sample'
# Out:
# there are 57 ratings in this sample

# %%
plt.hist(ratings)
plt.show()

# %%
def bootstrap(data, num_samples, statistic, alpha):
    """Returns bootstrap estimate of 100.0*(1-alpha) CI for statistic."""
    n = len(data)
    idx = npr.randint(0, n, (num_samples, n))
    samples = data[idx]
    stat = np.sort(statistic(samples, 1))
    return (stat[int((alpha/2.0)*num_samples)],
            stat[int((1-alpha/2.0)*num_samples)])

bootstrap(ratings,10000,)

if __name__ == '__main__':
    # data of interest is bimodal and obviously not normal
    #x = np.concatenate([npr.normal(3, 1, 100), npr.normal(6, 2, 200)])
    x = scores
    # find mean 95% CI and 100,000 bootstrap samples
    low, high = bootstrap(x, 100000, np.mean, 0.05)

    # make plots
    pylab.figure(figsize=(15,10))
    pylab.subplot(121)
    pylab.hist(x, 50)
    pylab.title('Historgram of data')
    pylab.subplot(122)
    pylab.plot([-0.03,0.03], [np.mean(x), np.mean(x)], 'r', linewidth=2)
    pylab.scatter(0.1*(npr.random(len(x))-0.5), x)
    pylab.plot([0.19,0.21], [low, low], 'r', linewidth=2)
    pylab.plot([0.19,0.21], [high, high], 'r', linewidth=2)
    pylab.plot([0.2,0.2], [low, high], 'r', linewidth=2)
    pylab.xlim([-0.2, 0.3])
    pylab.title('Bootstrap 95% CI for mean')
    #pylab.savefig('examples/boostrap.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f547db9e29cd> in <module>()
#      12     # data of interest is bimodal and obviously not normal
#      13     #x = np.concatenate([npr.normal(3, 1, 100), npr.normal(6, 2, 200)])
# ---> 14     x = scores
#      15     # find mean 95% CI and 100,000 bootstrap samples
#      16     low, high = bootstrap(x, 100000, np.mean, 0.05)
#
# NameError: name 'scores' is not defined

# %%
len(x)
# Out:
# 300
